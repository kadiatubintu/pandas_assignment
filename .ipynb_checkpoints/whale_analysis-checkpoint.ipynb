# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline
import matplotlib.pyplot as plt
import ctypes
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\kadib\anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
#print(ctypes.sizeof(ctypes.c_voidp))

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale, algo and SP500 returns
whale_returns = Path("Resources/whale_returns.csv")
# YOUR CODE HERE
whale_data = pd.read_csv(whale_returns,index_col = "Date", parse_dates = ['Date'] )
whale_data.head(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
# YOUR CODE HERE
#whale_null = 
whale_data.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
whale_data = whale_data.dropna()
whale_data.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns = Path("Resources/algo_returns.csv")
#algo_returns_csv = Path("Resources/algo_returns.csv")
# YOUR CODE HERE
algo_data = pd.read_csv(algo_returns, index_col= 'Date', parse_dates = ['Date'])
algo_data.head(5)
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
# YOUR CODE HERE
algo_null = algo_data.isna().sum()
algo_null
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
algo_data = algo_data.dropna()
algo_data.isna().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history = Path("Resources/sp500_history.csv")
#sp500_returns = pd.read_csv(sp500_history_csv)
# YOUR CODE HERE
sp500_data = pd.read_csv(sp500_history, index_col='Date', parse_dates = ['Date'] ).sort_values('Date') 
sp500_data.head(5)
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
# YOUR CODE HERE
sp500_data.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
# YOUR CODE HERE
sp500_data['Close'] = sp500_data['Close'].str.replace('$', '')
sp500_data
sp500_data['Close'] = sp500_data.Close.astype(float)
sp500_data.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
# YOUR CODE HERE
sp500_daily = sp500_data.pct_change()
sp500_daily.head(5)
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
# YOUR CODE HERE
sp500_dropna = sp500_daily.dropna()
sp500_dropna.head(5)

#sp500_data.isna()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename Column
# YOUR CODE HERE

#sp500_new = sp500_dropna.rename(columns={'Close': 'S&P500'})
#sp500_new.head(5)

sp500_new = sp500_dropna.rename(columns={'Close': 'S&P500'})
sp500_new.head(5)
# Out:
#               S&P500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
#making the columns all caps
algo_data = algo_data.rename(columns={'Algo 1': 'ALGO 1', 'Algo 2': 'ALGO 2'})

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
# YOUR CODE HERE
df = pd.merge(whale_data, algo_data, on = 'Date')
all_df = pd.merge(df,sp500_new, on = 'Date')
all_df.tail(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    ALGO 1  \
# Date
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               ALGO 2    S&P500
# Date
# 2019-04-16  0.002899  0.000509
# 2019-04-17 -0.005228 -0.002274
# 2019-04-18 -0.001229  0.001579
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?

# %%
# Plot daily returns
# YOUR CODE HERE
all_df.plot(title = "Daily Returns", figsize=(16,8),legend = True)
plt.legend(loc=3)

# %%
# Plot cumulative returns
all_cum = ((all_df + 1).cumprod() - 1)

# YOUR CODE HERE
all_cum.plot(title = "Cumulative Returns", figsize=(16,8),legend = True )
plt.legend(loc=2)

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
# YOUR CODE HERE
all_df_box = all_df.boxplot(figsize=(16,6), grid = False, fontsize = 8)
plt.suptitle("Portfolio Risk")
# Out:
# Text(0.5, 0.98, 'Portfolio Risk')

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
# YOUR CODE HERE
all_df_std = all_df.std().round(6)
all_df_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# ALGO 1                         0.007620
# ALGO 2                         0.008342
# S&P500                         0.008554
# dtype: float64

# %% [markdown]
# # Which portfolios are riskier than the S&P 500?
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919

# %%
# Determine which portfolios are riskier than the S&P 500
# YOUR CODE HERE
def risk(x):
    for cols in all_df_std:
        if cols > all_df_std['S&P500']:
            print (f'True')
        else:
            print(f'False')
           
risk(all_df)
# Out:
# False
# False
# True
# True
# False
# False
# False

# %%
# Calculate the annualized standard deviation (252 trading days)
# YOUR CODE HERE
all_df_ann = all_df_std*(252**0.5)
all_df_ann
# Out:
# SOROS FUND MANAGEMENT LLC      0.125329
# PAULSON & CO.INC.              0.111487
# TIGER GLOBAL MANAGEMENT LLC    0.172937
# BERKSHIRE HATHAWAY INC         0.205083
# ALGO 1                         0.120964
# ALGO 2                         0.132425
# S&P500                         0.135791
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# 3. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
# 4. An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21 day half-life.

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window 
# YOUR CODE HERE
all_roll = all_df.rolling(21).std()
all_roll.plot(title = "21 days Rolling Standard Deviation", figsize=(16,8), legend= True)
plt.legend(loc=2, fontsize=8)

# %%
# Construct a correlation table
# YOUR CODE HERE
     
all_df.corr(method = 'spearman')
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.672694
# PAULSON & CO.INC.                             0.672694            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.577076            0.446702
# BERKSHIRE HATHAWAY INC                        0.699655            0.496202
# ALGO 1                                        0.216868            0.174924
# ALGO 2                                        0.780848            0.642267
# S&P500                                        0.784832            0.634062
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.577076
# PAULSON & CO.INC.                               0.446702
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.454624
# ALGO 1                                          0.129233
# ...

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)
# YOUR CODE HERE
all_df_cov = np.var(all_df) 
all_df_cov
all_algo1_var = all_df_cov / berks_var
all_algo1_var.plot(title = "Algo 1", figsize=(16,8))

# %%
# Calculate a rolling window using the exponentially weighted moving average. 
# YOUR CODE HERE

exp_data=all_df.ewm(span=230,adjust=False).mean()
exp_data.plot(title = "Exponentially Weighted Average", figsize = (18,6),legend=True)
plt.legend(loc=2, fontsize=7)

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# 1. Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# 2. Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# %%
# Calculate annualized Sharpe Ratios
# YOUR CODE HERE
all_daily_rtns  = all_df.diff()
all_daily_rtns
sharpe_df = all_daily_rtns.mean() / all_daily_rtns.std()
annual_sharpe_df = sharpe_df*(252**0.05)
annual_sharpe_df
# Out:
# SOROS FUND MANAGEMENT LLC      0.000984
# PAULSON & CO.INC.              0.001102
# TIGER GLOBAL MANAGEMENT LLC    0.000565
# BERKSHIRE HATHAWAY INC         0.001381
# ALGO 1                         0.000855
# ALGO 2                         0.001177
# S&P500                         0.001387
# dtype: float64

# %%
all_df.count()
# Out:
# SOROS FUND MANAGEMENT LLC      1043
# PAULSON & CO.INC.              1043
# TIGER GLOBAL MANAGEMENT LLC    1043
# BERKSHIRE HATHAWAY INC         1043
# ALGO 1                         1043
# ALGO 2                         1043
# S&P500                         1043
# dtype: int64

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE
annual_sharpe_df.plot.bar(title = "Sharpe Ratio", )

# %% [markdown]
# On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? Type your answer here:

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Visit [Google Sheets](https://docs.google.com/spreadsheets/) and use the in-built Google Finance function to choose 3-5 stocks for your own portfolio.
# 2. Download the data as CSV files and calculate the portfolio returns.
# 3. Calculate the returns for each stock.
# 4. Using those returns, calculate the weighted returns for your entire portfolio assuming an equal number of shares for each stock.
# 5. Add your portfolio returns to the DataFrame with the other portfolios and rerun the analysis. How does your portfolio fair?
#
#
# ## Your analysis should include the following:
#
# - Using all portfolios:
#  - The annualized standard deviation (252 trading days) for all portfolios.
#  - The plotted rolling standard deviation using a 21 trading day window for all portfolios.
#  - The calculated annualized Sharpe Ratios and the accompanying bar plot visualization.
#  - A correlation table.
# - Using your custom portfolio and one other of your choosing:
#  - The plotted beta.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
# YOUR CODE HERE
file_path_cola = Path("Resources/cocacola1_hist.csv", )
cola_data = pd.read_csv(file_path_cola, index_col = "Date",  parse_dates = ['Date'], header = 0)
cola_data.head(5)
# Out:
#             Close
# Date
# 2015-08-24  38.38
# 2015-08-25  37.99
# 2015-08-26  38.73
# 2015-08-27  39.27
# 2015-08-28  39.45

# %%
# Read the second stock
# YOUR CODE HERE
file_path_nke = Path("Resources/nke1_hist.csv")
nke_data = pd.read_csv(file_path_nke, index_col = "Date", parse_dates = ['Date'],header = 0)
nke_data.head(5)
# Out:
#             Close
# Date
# 2016-06-20  54.36
# 2016-06-21  54.77
# 2016-06-22  54.57
# 2016-06-23  54.12
# 2016-06-24  52.59

# %%
# Read the third stock
# YOUR CODE HERE
file_path_twtr = Path("Resources/twtr1_hist.csv")
twtr_data = pd.read_csv(file_path_twtr, index_col = "Date",  parse_dates = ['Date'],  header = 0)
twtr_data.head(5)
# Out:
#             Close
# Date
# 2017-01-05  17.09
# 2017-01-06  17.17
# 2017-01-09  17.50
# 2017-01-10  17.37
# 2017-01-11  17.30

# %%
# Read the fourth stock
# YOUR CODE HERE
file_path_dell = Path("Resources/dell1_hist.csv")
dell_data = pd.read_csv(file_path_dell, index_col = "Date", parse_dates = ['Date'],  header = 0)

dell_data.head(5)
# Out:
#             Close
# Date
# 2018-12-21  42.17
# 2018-12-26  44.91
# 2018-12-27  44.60
# 2018-12-28  45.43
# 2018-12-31  48.87

# %%
#all = pd.DataFrame(cola_data, nke_data,dell_data,twtr_data)
# Concatenate all stocks into a single DataFrame
# YOUR CODE HERE
all_new_data = pd.concat([cola_data, nke_data,dell_data,twtr_data])
all_new_data.head(5)
# Out:
#             Close
# Date
# 2015-08-24  38.38
# 2015-08-25  37.99
# 2015-08-26  38.73
# 2015-08-27  39.27
# 2015-08-28  39.45

# %%
# Reset the index
# YOUR CODE HERE
new_data_reset = all_new_data.reset_index()
new_data_reset.head(5)
# Out:
#         Date  Close
# 0 2015-08-24  38.38
# 1 2015-08-25  37.99
# 2 2015-08-26  38.73
# 3 2015-08-27  39.27
# 4 2015-08-28  39.45

# %%
# Pivot so that each column of prices represents a unique symbol _table , columns=['DELL', 'TWTR', 'COLA', 'NKE'], unstack()
# YOUR CODE HERE, 
#new_data_cols = new_data_reset.pivot()
new_data_cols =pd.pivot_table(new_data_reset, "Close", index='Date',  aggfunc=np.mean)
new_data_cols.head(5)
# Out:
#             Close
# Date
# 2015-08-24  38.38
# 2015-08-25  37.99
# 2015-08-26  38.73
# 2015-08-27  39.27
# 2015-08-28  39.45

# %%
# Drop Nulls
# YOUR CODE HERE
new_data_dropna = new_data_cols.dropna()
new_data_dropna.head(5)
# Out:
#             Close
# Date
# 2015-08-24  38.38
# 2015-08-25  37.99
# 2015-08-26  38.73
# 2015-08-27  39.27
# 2015-08-28  39.45

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns - .product()
weights = [1/4, 1/4, 1/4, 1/4]
# YOUR CODE HERE
data_ewm= new_data_dropna.ewm(com=0.25).mean()
data_ewm.head(5)
# Out:
#                 Close
# Date
# 2015-08-24  38.380000
# 2015-08-25  38.055000
# 2015-08-26  38.599355
# 2015-08-27  39.136731
# 2015-08-28  39.387426

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns
# YOUR CODE HERE
data_ewm = data_ewm.rename(columns={'Close':'Custom'})
#combined_data = pd.concat([all_df, data_ewm], sort =True)
combined_data = pd.merge(all_df, data_ewm, on = "Date")
combined_data.head(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-08-24                  -0.029426           -0.015219
# 2015-08-25                  -0.006770           -0.004944
# 2015-08-26                   0.022246            0.016487
# 2015-08-27                   0.024140            0.011821
# 2015-08-28                   0.004108           -0.000438
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    ALGO 1  \
# Date
# 2015-08-24                    -0.029381               -0.038900  0.001511
# 2015-08-25                    -0.006170                0.022718  0.010168
# 2015-08-26                     0.029021                0.031408  0.019371
# 2015-08-27                     0.017402                0.039968  0.031120
# 2015-08-28                    -0.001647               -0.007137  0.017296
#
#               ALGO 2    S&P500     Custom
# Date
# 2015-08-24 -0.036937 -0.039414  38.380000
# 2015-08-25 -0.001084 -0.013522  38.055000
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
# YOUR CODE HERE
combined_dropna = combined_data.dropna()

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
# YOUR CODE HERE
combined_std = combined_dropna.std()*(252**0.5)
combined_std
# Out:
# SOROS FUND MANAGEMENT LLC       0.128597
# PAULSON & CO.INC.               0.116002
# TIGER GLOBAL MANAGEMENT LLC     0.180368
# BERKSHIRE HATHAWAY INC          0.212500
# ALGO 1                          0.123011
# ALGO 2                          0.135503
# S&P500                          0.137285
# Custom                         89.037031
# dtype: float64

# %%
# Rolling
# YOUR CODE HERE
combined_roll = combined_std.rolling(21)

# %%
# Annualized Sharpe Ratios
# YOUR CODE HERE

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE

# %%
# Create a correlation analysis
# YOUR CODE HERE

# %%
# Beta
# YOUR CODE HERE
